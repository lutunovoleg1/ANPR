# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/Car_licence_plate_obd/dataset/dataset.zip' -d '/content/drive/MyDrive/Car_licence_plate_obd/dataset'
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#  extracting: /content/drive/MyDrive/Car_licence_plate_obd/dataset/train/images/5667_jpg.rf.c5645b3afa9c0255662ba5106a29d90c.jpg
#  extracting: /content/drive/MyDrive/Car_licence_plate_obd/dataset/train/images/5668_jpg.rf.42bd2cab39939b31584701712dc31239.jpg
#  extracting: /content/drive/MyDrive/Car_licence_plate_obd/dataset/train/images/5670_jpg.rf.90c387a313cd422028fffe16aa78427b.jpg
#  extracting: /content/drive/MyDrive/Car_licence_plate_obd/dataset/train/images/5671_jpg.rf.8463aa1f38c3465c9d7060960e78331b.jpg
#  extracting: /content/drive/MyDrive/Car_licence_plate_obd/dataset/train/images/5672_jpg.rf.81fe7948ae8d1edbdb6a21661d8ab17e.jpg
#  extracting: /content/drive/MyDrive/Car_licence_plate_obd/dataset/train/images/5673_jpg.rf.fc9aba801bcabd065c7b4004c12c0a3d.jpg
#  extracting: /content/drive/MyDrive/Car_licence_plate_obd/dataset/train/images/5675_jpg.rf.027560ffbf9635b4ecadfbfd4be6173d.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 14.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO


def train_model():
    # Load a model
    model = YOLO('yolov8n.pt')  # Load pretrained model

    # Train the model
    results = model.train(task='detect',
                          model='yolov8n.pt',
                          mode='train',
                          data='/content/drive/MyDrive/Car_licence_plate_obd/dataset/data.yaml',
                          epochs=150,
                          imgsz=640,
                          batch = 32,
                          device=0,
                          project='/content/drive/MyDrive/Car_licence_plate_obd/runs',
                          name = 'yolov8_s',
                          hsv_h = 0.2, # (float) image HSV-Hue augmentation (fraction)
                          hsv_s = 0.2, # (float) image HSV-Saturation augmentation (fraction)
                          hsv_v = 0.2, # (float) image HSV-Value augmentation (fraction)
                          degrees = 20.0, # (float) image rotation (+/- deg)
                          translate = 0.2, # (float) image translation (+/- fraction)
                          scale = 0.7, # (float) image scale (+/- gain)
                          shear = 8.0, # (float) image shear (+/- deg)
                          perspective = 0.0, # (float) image perspective (+/- fraction), range 0-0.001
                          flipud = 0.0, # (float) image flip up-down (probability)
                          fliplr = 0, # (float) image flip left-right (probability)
                          bgr = 0.0, # (float) image channel BGR (probability)
                          mosaic = 1, # (float) image mosaic (probability)
                          mixup = 0, # (float) image mixup (probability)
                          copy_paste = 0.0, # (float) segment copy-paste (probability)
                          auto_augment = 'randaugment', # (str) auto augmentation policy for classification (randaugment, autoaugment, augmix)
                          erasing = 0.15, # (float) probability of random erasing during classification training (0-0.9), 0 means no erasing, must be less than 1.0.
                          crop_fraction = 1, # (float) image crop fraction for classification (0.1-1), 1.0 means no crop, must be greater than 0,
                          close_mosaic = 10)
    return results


if __name__ == '__main__':
    train_model()
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
